# %%
#default arg:
def default(a=10,b=20):
    return a*b
default()
default(30)
# Out:
# 600

# %%
#default arg:
def default(a=10,b=20):
    return a*b
default()
default(30)
default(0,60)
# Out:
# 0

# %%
#3.variable length arg
def var_len(a=20,b=20,*c):
    return a,b,c
a= var_len(20,20,10)
print(a,b,c)

def var_len(e,f)
# Out:
# (10, 20, (10, 10)) 20 (10, 10)

# %%
strings
-collection of characters
enclosed with singl;e quotes or double quotes
# Out:
#   File "<ipython-input-1-8342b0d0b153>", line 2
#     -collection of characters
#                  ^
# SyntaxError: invalid syntax

# %%
s=''
print(type(s))
# Out:
# <class 'str'>

# %%
g="APSSDC"
print(g)
g
# Out:
# APSSDC
# 'APSSDC'

# %%
g[3]
# Out:
# 'S'

# %%
g[-6]
# Out:
# 'A'

# %%
print(g)
g[3:6]
# Out:
# APSSDC
# 'SDC'

# %%
g[-4:-1]
# Out:
# 'SSD'

# %%
g[::-5]
# Out:
# 'CA'

# %%
g1="abcABC"
g1.upper()
# Out:
# 'ABCABC'

# %%
print(g)
g.lower()
# Out:
# APSSDC
# 'apssdc'

# %%
dir(g)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
g3='apssdc python wprkshop'
g3.title()
# Out:
# 'Apssdc Python Wprkshop'

# %%
a="rvr"
b="ece"
c=a+b
print(c)
# Out:
# rvrece

# %%
c.split()
# Out:
# ['rvrece']

# %%
a="rvr"
b="ece"
c=a+ ''+b
print(c)
# Out:
# rvrece

# %%
g3.split()
# Out:
# ['apssdc', 'python', 'wprkshop']

# %%
y="  python workshop   "
len(y)
# Out:
# 20

# %%
y.lstrip()
# Out:
# 'python workshop   '

# %%
a=['srirama','krishna']
"@".join(a)
# Out:
# 'srirama@krishna'
